# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import PIL
import requests

# %%
df = pd.read_csv("https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/movie_quotes.csv", on_bad_lines='skip')
df.head(3)
# Out:
#                                                quote  \
# 0                    Do, or do not. There is no try.
# 1  Listen to them. Children of the night. What mu...
# 2                            It's alive! It's alive!
#
#                                             movie   type  year
# 0  Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                         Dracula  movie  1931
# 2                                    Frankenstein  movie  1931

# %%
text = " ".join(each for each in df.quote)
text
# Out:
# 'Do, or do not. There is no try. Listen to them. Children of the night. What music they make. It\'s alive! It\'s alive! Oh, no, it wasn\'t the airplanes. It was Beauty killed the Beast. Magic Mirror on the wall, who is the fairest one of all? Elementary, my dear Watson. I\'ll get you, my pretty, and your little dog, too! After all, tomorrow is another day! Frankly, my dear, I don\'t give a damn. Toto, I\'ve got a feeling we\'re not in Kansas anymore. There\'s no place like home. As God is my witness, I\'ll never be hungry again. It\'s gone forever, that funny young, lost look I loved won\'t ever come back. I killed that when I told you about Rebecca. It\'s gone. In a few hours, you\'ve grown so much older. Here\'s looking at you, kid. Play it, Sam. Play \'As Time Goes By. We\'ll always have Paris. Round up the usual suspects. This is the beginning of a beautiful friendship. When it comes to women, you’re a true democrat. I am big! It\'s the pictures that got small. Nobody ever lies a
# ...

# %%
wordcloud = WordCloud(background_color='white',
                      colormap='inferno').generate(text)

fig, ax = plt.subplots(figsize=(10,5))
ax.imshow(wordcloud, interpolation='bilinear')
ax.axis('off')
fig.show()

# %%
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted

# %%
A = set(["apple", "banana", "watermelon"])
B = set(["pumpkin", "blueberry", "apple", "key lime"])

diagram = venn2_unweighted([A,B],
                           set_labels = ('Fruits', 'Pies'),
                           set_colors = ('blue', 'red'),
                           alpha = 0.5)

diagram.get_label_by_id("10").set_text("\n".join(A-B))
diagram.get_label_by_id("11").set_text("\n".join(A & B))
diagram.get_label_by_id("01").set_text("\n".join(B-A))

# %%
# !pip install plottable

# %%
from plottable import Table
from plottable import ColumnDefinition
import textwrap as twp

# %%
df = pd.read_csv("https://raw.githubusercontent.com/IvanJoskic/pet-data-set/main/pet-set.csv",
                 on_bad_lines = 'skip',
                 usecols = ['breedname', 'weight', 'gender'])

df = df.set_index("breedname")

df
# Out:
#                         weight  gender
# breedname
# German Shepherd           35.0    male
# East European Shepherd    41.0    male
# German Shepherd           27.0  female
# Croatian Sheepdog         16.5     m/f
# Burmese                    5.0     m/f
# Affenpinscher              3.7     m/f
# Afghan Hound              24.0     m/f
# Basset Hound              30.0    male
# Basset Hound              24.5  female
# French Bulldog            12.0     m/f

# %%
fig, ax = plt.subplots(figsize = (15,5))

ax.tab = Table(df)

# %%
column_names = [ColumnDefinition(name = "breedname",
                                 title = "Breed Name",
                                 textprops = {"ha": "center", "weight":"bold", "size":12}),
                ColumnDefinition(name = "weight",
                                 title = "Weight",
                                 textprops = {"ha":"center"}),
                ColumnDefinition(name = "gender",
                                 title = "Gender",
                                 textprops = {"ha":"center"})]

fig, ax = plt.subplots(figsize = (10,5))
ax.tab = Table(df,
               column_definitions = column_names)

# %%
column_names = [ColumnDefinition(name = "breedname",
                                 title = "Breed Name",
                                 textprops = {"ha": "center", "weight":"bold", "size":12}),
                ColumnDefinition(name = "weight",
                                 title = "Weight",
                                 textprops = {"ha":"center",
                                              "bbox":{"boxstyle":"circle","pad":0.35,"color":"skyblue"}}),
                ColumnDefinition(name = "gender",
                                 title = "Gender",
                                 textprops = {"ha":"center"})]

fig, ax = plt.subplots(figsize = (10,5))
ax.tab = Table(df,
               column_definitions = column_names)

# %%
column_names = [ColumnDefinition(name = "breedname",
                                 title = "Breed Name",
                                 textprops = {"ha": "center", "weight":"bold", "size":12}),
                ColumnDefinition(name = "weight",
                                 title = "Weight",
                                 textprops = {"ha":"center",
                                              "bbox":{"boxstyle":"circle","pad":0.35,"color":"skyblue"}}),
                ColumnDefinition(name = "gender",
                                 title = "Gender",
                                 textprops = {"ha":"center"})]

fig, ax = plt.subplots(figsize = (10,8))
ax.tab = Table(df,
               column_definitions = column_names,
               row_divider_kw = {"linewidth":1, "linestyle":"dashed"})
